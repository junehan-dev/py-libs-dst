# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..', '')))
from visualizer import render
from tree_node import TreeNode
from create_bst import create_bst, create_bst_bfs

# %%
for i in range(1, 8):
    t = create_bst([_ for _ in range(0,i)])
    render(t);

# %%
t = create_bst([-10,-3,0,5,9]);
render(t);
t = create_bst([1,3]);
render(t);
create_bst([]);
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [3], in <cell line: 5>()
#       3 t = create_bst([1,3]);
#       4 render(t);
# ----> 5 create_bst([])
#
# File ~/Documents/CURRENT/Lectures/LC/py-libs-dst/tree/create_bst.py:4, in create_bst(sorted_arr)
#       3 def create_bst(sorted_arr):
# ----> 4     assert(len(sorted_arr) > 0);
#       5     root = TreeNode(sorted_arr[len(sorted_arr) // 2]);
#       6     create_bst_dfs(root, sorted_arr) if len(sorted_arr) > 1 else None;
#
# AssertionError:

# %%
t = create_bst_bfs([-10,-3,0,5,9]);
render(t);
t = create_bst_bfs([1,3]);
render(t);
t = create_bst_bfs([]);
render(t);
#t = create_bst_bfs([1,3]);
#render(t);
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [4], in <cell line: 5>()
#       3 t = create_bst_bfs([1,3]);
#       4 render(t);
# ----> 5 t = create_bst_bfs([]);
#       6 render(t)
#
# File ~/Documents/CURRENT/Lectures/LC/py-libs-dst/tree/create_bst.py:25, in create_bst_bfs(sorted_arr)
#      24 def create_bst_bfs(sorted_arr):
# ---> 25     root = TreeNode(sorted_arr[len(sorted_arr) // 2]);
#      26     q_subtree = deque([(root, sorted_arr)]);
#      28     while q_subtree:
#
# IndexError: list index out of range

# %%
for i in range(1, 8):
    t = create_bst_bfs([_ for _ in range(0,i)])
    render(t);

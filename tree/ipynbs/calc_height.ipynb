# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..', '')))
from visualizer import render
from tree_node import TreeNode
from create_btree import create_tree
from collections import deque
from invert import (invert_tree, invert_tree_dfs);
from is_balanced import (is_balanced, dfs_get_h, dfs_get_l_r_h);
from rotate import right_rotate, left_rotate

# %%
bst = create_tree([10,5,15,2,6,12,17,1,None,None,8]);

# %%
render(bst);
ret = invert_tree(bst);

# %%
invert_tree_dfs(ret);
render(ret);

# %%
# %load ../get_height
from tree_node import TreeNode

# %%
simple_tree = create_tree([1,2,3,4,5,None,None,6,7]);
print(simple_tree.val)
# Out:
# 1

# %%
h = dfs_get_h(simple_tree);
render(simple_tree);
print(h);
# Out:
# 3
